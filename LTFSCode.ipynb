# %%
import pandas as pd
import numpy as np
ltfsFile=pd.read_csv('train_LTFS.csv')
ltFsTestFile=pd.read_csv('test_LTFS.csv')

# %%
ltfsFile['Date.of.Birth']=ltfsFile['Date.of.Birth'].str.strip()
ltfsFile['Date.of.Birth']=pd.to_datetime(ltfsFile['Date.of.Birth'],format='%d%m%Y',errors='ignore')


ltfsFile['Employment.Type']=ltfsFile['Employment.Type'].apply(lambda x:-1 if(pd.isnull(x)) else x)
ltfsFile['Employment.Type']=ltfsFile['Employment.Type'].apply(lambda x:1 if(x=='Salaried') else x)
ltfsFile['Employment.Type']=ltfsFile['Employment.Type'].apply(lambda x:2 if(x=='Self employed') else x)


ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:0 if(x=='No Bureau History Available') else x)
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:1 if(x=='I-Medium Risk') else x)
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:2 if(x=='L-Very High Risk') else x)         
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:3 if(x=='A-Very Low Risk') else x)                                                                                                       
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:4 if(x=='Not Scored: Not Enough Info available on the customer') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:5 if(x=='D-Very Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:6 if(x=='M-Very High Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:7 if(x=='B-Very Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:8 if(x=='C-Very Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:9 if(x=='E-Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:10 if(x=='H-Medium Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:11 if(x=='F-Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:12 if(x=='K-High Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:13 if(x=='Not Scored: No Activity seen on the customer (Inactive)') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:14 if(x=='Not Scored: Sufficient History Not Available') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:15 if(x=='Not Scored: No Updates available in last 36 months') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:16 if(x=='G-Low Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:17 if(x=='J-High Risk') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:18 if(x=='Not Scored: Only a Guarantor') else x) 
ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltfsFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:19 if(x=='Not Scored: More than 50 active Accounts found') else x) 

ltfsFile['AVERAGE.ACCT.AGE']=ltfsFile['AVERAGE.ACCT.AGE'].apply(lambda x: x.replace('yrs',''))
ltfsFile['AVERAGE.ACCT.AGE']=ltfsFile['AVERAGE.ACCT.AGE'].apply(lambda x: x.replace('mon',''))
ltfsFile['AVERAGE.ACCT.AGE']=ltfsFile['AVERAGE.ACCT.AGE'].apply( lambda x: int(x.split(' ')[0])*12 + int(x.split(' ')[1])*30)

ltfsFile['CREDIT.HISTORY.LENGTH']=ltfsFile['CREDIT.HISTORY.LENGTH'].apply(lambda x: x.replace('yrs',''))
ltfsFile['CREDIT.HISTORY.LENGTH']=ltfsFile['CREDIT.HISTORY.LENGTH'].apply(lambda x: x.replace('mon',''))
ltfsFile['CREDIT.HISTORY.LENGTH']=ltfsFile['CREDIT.HISTORY.LENGTH'].apply( lambda x: int(x.split(' ')[0])*12 + int(x.split(' ')[1])*30)

# %%
i=0
for value in ltfsFile['Date.of.Birth']:
   age=returnAge(ltfsFile['Date.of.Birth'][i])
   print(age)
   ltfsFile['Date.of.Birth'][i]=age
   i=i+1

#ltfsFile['Date.of.Birth']
# Out:
# 35
# 33
# 33
# 25
# 41
# 28
# 31
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 30
# 27
# -48
# 40
# 34
# 45
# 34
# 46
# 24
# 43
# 36
# 30
# 38
# 41
# 35
# 24
# 39
# 30
# 33
# -48
# 43
# 46
# 49
# 45
# 28
# -46
# 22
# 42
# 25
# 32
# 28
# 41
# 22
# 50
# 25
# 36
# 29
# 42
# 28
# 26
# 33
# 45
# 38
# 33
# 47
# 30
# 25
# 34
# 34
# 24
# 25
# 43
# -44
# 42
# 41
# 35
# 47
# 24
# 34
# 34
# 28
# -47
# 34
# 36
# 24
# -47
# 39
# 26
# 30
# 46
# 33
# 36
# 33
# 49
# 49
# 26
# 41
# 50
# 22
# 41
# 20
# 20
# 36
# 24
# 20
# 40
# 26
# 43
# 35
# 41
# -48
# 28
# 21
# 42
# 29
# 25
# 39
# 41
# 30
# 40
# 43
# 36
# 29
# 41
# -47
# 30
# 25
# 28
# 30
# 50
# 47
# 38
# 38
# 23
# 31
# 32
# 35
# 42
# 21
# 47
# 36
# -42
# 42
# 36
# 23
# ...

# %%
def returnAge(birth_date):
    
    days_in_year = 365.2425    
    age = int((pd.to_datetime('today') -pd.to_datetime(birth_date) ).days / days_in_year)
    return age

# %%
ltFsTestFile['Date.of.Birth']=ltFsTestFile['Date.of.Birth'].str.strip()
ltFsTestFile['Date.of.Birth']=pd.to_datetime(ltFsTestFile['Date.of.Birth'],format='%d%m%Y',errors='ignore')


ltFsTestFile['Employment.Type']=ltFsTestFile['Employment.Type'].apply(lambda x:-1 if(pd.isnull(x)) else x)
ltFsTestFile['Employment.Type']=ltFsTestFile['Employment.Type'].apply(lambda x:1 if(x=='Salaried') else x)
ltFsTestFile['Employment.Type']=ltFsTestFile['Employment.Type'].apply(lambda x:2 if(x=='Self employed') else x)


ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:0 if(x=='No Bureau History Available') else x)
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:1 if(x=='I-Medium Risk') else x)
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:2 if(x=='L-Very High Risk') else x)         
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:3 if(x=='A-Very Low Risk') else x)                                                                                                       
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:4 if(x=='Not Scored: Not Enough Info available on the customer') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:5 if(x=='D-Very Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:6 if(x=='M-Very High Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:7 if(x=='B-Very Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:8 if(x=='C-Very Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:9 if(x=='E-Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:10 if(x=='H-Medium Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:11 if(x=='F-Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:12 if(x=='K-High Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:13 if(x=='Not Scored: No Activity seen on the customer (Inactive)') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:14 if(x=='Not Scored: Sufficient History Not Available') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:15 if(x=='Not Scored: No Updates available in last 36 months') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:16 if(x=='G-Low Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:17 if(x=='J-High Risk') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:18 if(x=='Not Scored: Only a Guarantor') else x) 
ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION']=ltFsTestFile['PERFORM_CNS.SCORE.DESCRIPTION'].apply(lambda x:19 if(x=='Not Scored: More than 50 active Accounts found') else x) 

ltFsTestFile['AVERAGE.ACCT.AGE']=ltFsTestFile['AVERAGE.ACCT.AGE'].apply(lambda x: x.replace('yrs',''))
ltFsTestFile['AVERAGE.ACCT.AGE']=ltFsTestFile['AVERAGE.ACCT.AGE'].apply(lambda x: x.replace('mon',''))
ltFsTestFile['AVERAGE.ACCT.AGE']=ltFsTestFile['AVERAGE.ACCT.AGE'].apply( lambda x: int(x.split(' ')[0])*12 + int(x.split(' ')[1])*30)

ltFsTestFile['CREDIT.HISTORY.LENGTH']=ltFsTestFile['CREDIT.HISTORY.LENGTH'].apply(lambda x: x.replace('yrs',''))
ltFsTestFile['CREDIT.HISTORY.LENGTH']=ltFsTestFile['CREDIT.HISTORY.LENGTH'].apply(lambda x: x.replace('mon',''))
ltFsTestFile['CREDIT.HISTORY.LENGTH']=ltFsTestFile['CREDIT.HISTORY.LENGTH'].apply( lambda x: int(x.split(' ')[0])*12 + int(x.split(' ')[1])*30)

# %%
X_train=ltfsFile[['disbursed_amount','asset_cost','ltv','Employment.Type','Aadhar_flag','PERFORM_CNS.SCORE','PERFORM_CNS.SCORE.DESCRIPTION','PRI.NO.OF.ACCTS','PRI.ACTIVE.ACCTS','PRI.OVERDUE.ACCTS','PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT','PRI.DISBURSED.AMOUNT','PRIMARY.INSTAL.AMT','DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS','AVERAGE.ACCT.AGE','CREDIT.HISTORY.LENGTH','NO.OF_INQUIRIES']]

# %%
y_train=ltfsFile[['loan_default']]

# %%
X_test=ltFsTestFile[['disbursed_amount','asset_cost','ltv','Employment.Type','Aadhar_flag','PERFORM_CNS.SCORE','PERFORM_CNS.SCORE.DESCRIPTION','PRI.NO.OF.ACCTS','PRI.ACTIVE.ACCTS','PRI.OVERDUE.ACCTS','PRI.CURRENT.BALANCE','PRI.SANCTIONED.AMOUNT','PRI.DISBURSED.AMOUNT','PRIMARY.INSTAL.AMT','DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS','AVERAGE.ACCT.AGE','CREDIT.HISTORY.LENGTH','NO.OF_INQUIRIES']]

# %%
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
# 16 Neurons, expects input of 11 features. 
# Play around with the number of neurons!!
model.add(Dense(18, input_dim=18, activation='relu'))
# Add another Densely Connected layer (every neuron connected to every neuron in the next layer)
model.add(Dense(48, activation='relu'))
# Last layer simple sigmoid function to output 0 or 1 (our label)
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train,epochs=50,verbose=2)

predictions=model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 10s - loss: 6.7838 - acc: 0.5760
# Epoch 2/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 3/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 4/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 5/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 6/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 7/50
#  - 11s - loss: 3.4988 - acc: 0.7829
# Epoch 8/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 9/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 10/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 11/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 12/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 13/50
#  - 10s - loss: 3.4988 - acc: 0.7829
# Epoch 14/50
# ...

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
predictions=rfc.predict(X_test)

# %%
ltFsTestFile['loan_default']=predictions

# %%
ltFsTestFile[['UniqueID','loan_default']].to_csv("SubmissionsLTFS.csv",index=False)
